# %% [markdown]
# ## Sets and Dictionaries

# %% [markdown]
# Creating Dictionaries

# %%
d1={}
print(d1)
print(type(d1))
# Out:
# {}
# <class 'dict'>

# %%
d2={1:"welcome",2:"Python",3:"Dictionaries"}
d2
# Out:
# {1: 'welcome', 2: 'Python', 3: 'Dictionaries'}

# %%
d3={"name":"vikas","age":20,"gender":"Male"}
d3
# Out:
# {'name': 'vikas', 'age': 20, 'gender': 'Male'}

# %%
d4=dict({1:"welcome",2:"Python",3:"Dictionaries"})
d4
# Out:
# {1: 'welcome', 2: 'Python', 3: 'Dictionaries'}

# %%
d5=dict(
    [
        (1,'welcome'),
        (2,"to"),
        (3,"vikas code")
    ]
)
d5
# Out:
# {1: 'welcome', 2: 'to', 3: 'vikas code'}

# %%
d6 = {"name":{"first":"vikas","last":"jethava"},"age":20,"gender":"Male"}
d6
# Out:
# {'name': {'first': 'vikas', 'last': 'jethava'}, 'age': 20, 'gender': 'Male'}

# %% [markdown]
# **Adding elements**

# %%
d={}
d[0]="welcome"
print(d)
# Out:
# {0: 'welcome'}

# %%
d[1]=("how","are","you")
d
# Out:
# {0: 'welcome', 1: ('how', 'are', 'you')}

# %%
d["name"]="vikas" #create
d
# Out:
# {0: 'welcome', 1: ('how', 'are', 'you'), 'name': 'vikas'}

# %%
d["name"]="vishal"  #upadting
d
# Out:
# {0: 'welcome', 1: ('how', 'are', 'you'), 'name': 'vishal'}

# %% [markdown]
# **Accessing Elements**

# %%
print(d)
# Out:
# {0: 'welcome', 1: ('how', 'are', 'you'), 'name': 'vishal'}

# %%
print(d["name"])
# Out:
# vishal

# %%
print(d["name"])
# Out:
# vishal

# %%
print(d.get(1))
# Out:
# ('how', 'are', 'you')

# %% [markdown]
# **Deleting element**

# %%
d
# Out:
# {0: 'welcome', 1: ('how', 'are', 'you'), 'name': 'vishal'}

# %%
d.pop(0)
# Out:
# 'welcome'

# %%
d
# Out:
# {1: ('how', 'are', 'you'), 'name': 'vishal'}

# %%
d.popitem() #lastdeleted
# Out:
# ('name', 'vishal')

# %%
d
# Out:
# {1: ('how', 'are', 'you')}

# %% [markdown]
# **using built in function**

# %%
d.values()
# Out:
# dict_values([('how', 'are', 'you')])

# %%
keys={'a','b','c','d'}
value=1
dict.fromkeys(keys,value)
# Out:
# {'a': 1, 'd': 1, 'b': 1, 'c': 1}

# %%
d.clear()

# %%
d
# Out:
# {}

# %% [markdown]
# ## Sets

# %%
# unordered collection of unique elements

# %%
s=set([1,2,3,4,5])
print(type(s))
print(s)
# Out:
# <class 'set'>
# {1, 2, 3, 4, 5}

# %%
s.add('a')

# %%
s
# Out:
# {1, 2, 3, 4, 5, 'a'}

# %%
fs=frozenset([1,2,3,4,5])
print(fs)
# Out:
# frozenset({1, 2, 3, 4, 5})

# %%
fs.add('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 fs.add('a')
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s1=set([1,2,3,4])
s2=set([3,5,6,4])
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s1.
