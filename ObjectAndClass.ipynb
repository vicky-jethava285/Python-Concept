# %% [markdown]
# ## Python Obejcts And Classes

# %%
# Just like everything in the real world is an object , so is the case with oops programming paradigm

# %%
# A Class is a blueprint for similer objects

# %%
# Example :

# %%
class Person:
    def __init__(self):
        self.name = "vikas"
        self.gender = "Male"
        self.age = 20
    def talk(self):
        print("Hi i'm ",self.name)

    def vote(self):
        if self.age >= 18:
            print("I am eligible to vote")
        else:
            print("I am not eligible to vote")
obj = Person()
# Person.talk(obj)
# Person.vote(obj)
obj.talk()
obj.vote()
# Out:
# Hi i'm  vikas
# I am eligible to vote

# %%
class Person:
    def __init__(self,n,g,a):
        self.name = n
        self.gender = g
        self.age = a
    def talk(self):
        print("Hi i'm",self.name)

    def vote(self):
        if self.age >= 18:
            print("I am eligible to vote")
        else:
            print("I am not eligible to vote")
print(obj.name,obj2.name) 

obj = Person("sanket","Male",22)
obj.talk()
obj.vote()

obj2 = Person("Rutvika","Female",24)
obj2.talk()
obj2.vote()
# Out:
# sanket Rutvika
# Hi i'm sanket
# I am eligible to vote
# Hi i'm Rutvika
# I am eligible to vote
